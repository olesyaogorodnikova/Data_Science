# %%
import pickle

# %%
import numpy as np
from numpy import mean
import pandas as pd
import nltk

# %%
df = pd.read_pickle("df_clean_newwer_new_last.pkl")
df.shape
# Out:
# (333458, 10)

# %%
test_df = df[df['identifier'] == df['identifier'].iloc[45]]
test_df = test_df.drop(['file', "speaker_id"], axis=1)

# %%
test_df_all = df[df['identifier'] == df['identifier']]
test_df_all = test_df_all.drop(['file', "speaker_id"], axis=1)

# %%
ref =test_df["reference.text"]

# %%
len(ref)
# Out:
# 13

# %%
hyp =test_df["hypothesis.text"]

# %%
ref_all =test_df_all["reference.text"].values.tolist()

# %%
hyp_all =test_df_all["hypothesis.text"].values.tolist()

# %%
print(hyp)
# Out:
# 2803        i forget i think it was something like 12 years or something
# 2803        i forget i think it was something like 12 years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803    i forget i think it was something like twelve years or something
# 2803                             i forget i think it's like twelve years
# 2803                             i forget i think it's like twelve years
# 2803    i forget i think it was something like twelve years or something
# ...

# %%
hyp =test_df["hypothesis.text"].values.tolist()

# %%
ref =test_df["reference.text"].values.tolist()

# %%
tokenized_ref = [nltk.word_tokenize(i) for i in ref]
for i in tokenized_sents:
    print(i)
# Out:
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'why', "'s", 'that']
# ...

# %%
tokenized_hyp = [nltk.word_tokenize(i) for i in hyp]
for i in tokenized_sents:
    print(i)
# Out:
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'why', "'s", 'that']
# ...

# %%
tokenized_ref_all = [nltk.word_tokenize(i) for i in ref_all]
for i in tokenized_sents:
    print(i)
# Out:
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'why', "'s", 'that']
# ...

# %%
tokenized_hyp_all = [nltk.word_tokenize(i) for i in hyp_all]
for i in tokenized_sents:
    print(i)
# Out:
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'why', "'s", 'that']
# ...

# %%
tokenized_ref=[x for s in tokenized_sent_ref for x in s]

# %%
tokenized_hyp=[x for s in tokenized_sent_hyp for x in s]

# %%
print(tokenized_ref)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
test=test_df["hypothesis.text"].values.tolist()

# %%
test
# Out:
# ['i forget i think it was something like 12 years or something',
#  'i forget i think it was something like 12 years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  'i forget i think it was something like twelve years or something',
#  "i forget i think it's like twelve years",
#  "i forget i think it's like twelve years",
#  'i forget i think it was something like twelve years or something']

# %%
tokenized_sents = [nltk.word_tokenize(i) for i in test]
for i in tokenized_sents:
    print(i)
# Out:
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that']
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'why', "'s", 'that']
# ...

# %%
tokenized_sent=[x for s in tokenized_sents for x in s]

# %%
print(tokenized_sent)
# Out:
# ['one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that', 'one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that', 'one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that', 'one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'a', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that', 'one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'was', 'that', 'one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'uh', 'many', 'people', 'complain', 'about', 'the', 'school', 'systems', 'why', "'s", 'that', 'one', 'of', 'the', 'things', 'that', 'i', "'ve", 'heard', 'of', 'many', 'people', 'complain', 'about', 'the', 'schoo
# ...

# %%
test
# Out:
# ["one of the things that i've heard uh many people complain about the school systems was that",
#  "one of the things that i've heard uh many people complain about the school systems was that",
#  "one of the things that i've heard a many people complain about the school systems was that",
#  "one of the things that i've heard a many people complain about the school systems was that",
#  "one of the things that i've heard many people complain about the school systems was that",
#  "one of the things that i've heard uh many people complain about the school systems why's that",
#  "one of the things that i've heard of many people complain about the school system's was that",
#  "one of the things that i've heard of many people complain about the school system's was that",
#  "but one of the things that i've heard a many people complain about the school system was that",
#  "but one of the things that i've heard a many people complain about the school system was that",
# ...

# %%
from collections import Counter

# %%
counts = Counter(tokenized_sent)

# %%
len(tokenized_sent)
# Out:
# 217

# %%
dfw=pd.DataFrame(counts.items())

# %%
dfw.columns= ["word","count"]

# %%
dfw.groupby(["word"]).agg({"count":sum}).sort_values("count", ascending=False)
# Out:
#           count
# word
# that         24
# the          22
# one          15
# of           15
# people       13
# many         13
# complain     11
# heard        11
# i            11
# about        11
# things       11
# 've          11
# school       11
# was          10
# systems       7
# a             4
# system        4
# 's            3
# uh            3
# part          2
# thing         2
# but           2
# why           1

# %%
import chars2vec
import sklearn.decomposition
import matplotlib.pyplot as plt
 
# Load Inutition Engineering pretrained model
# Models names: 'eng_50', 'eng_100', 'eng_150'
c2v_model = chars2vec.load_model('eng_50')


# Create word embeddings
word_embeddings = c2v_model.vectorize_words(tokenized_sent)
 
# Project embeddings on plane using the PCA
projection_2d = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)
 
# Draw words on plane
f = plt.figure(figsize=(20, 20))
 
for j in range(len(projection_2d)):
    plt.scatter(projection_2d[j, 0], projection_2d[j, 1],
                marker=('$' + tokenized_sent[j] + '$'),
                s=450 * len(tokenized_sent[j]), label=j,
                facecolors='green' if tokenized_sent[j]
                           in ref else 'black')


plt.show()

# %%
from fuzzywuzzy import fuzz

# %%
def get_ratio(row):
    refer = row['reference.text']
    hypot = row['hypothesis.text']
    return fuzz.partial_ratio(refer, hypot)

# %%
pd.options.display.max_colwidth = 200

# %%
df1=pd.DataFrame()

# %%
test_df['hypothesis.text'].reset_index(drop=True)
# Out:
# 0       one of the things that i've heard uh many people complain about the school systems was that
# 1       one of the things that i've heard uh many people complain about the school systems was that
# 2        one of the things that i've heard a many people complain about the school systems was that
# 3        one of the things that i've heard a many people complain about the school systems was that
# 4          one of the things that i've heard many people complain about the school systems was that
# 5     one of the things that i've heard uh many people complain about the school systems why's that
# 6      one of the things that i've heard of many people complain about the school system's was that
# 7      one of the things that i've heard of many people complain about the school system's was that
# 8     but one of the things that i've heard a many people complain about the school system was that
# ...

# %%
df_2 = pd.DataFrame()
df_2 = pd.DataFrame(columns=['reference.text', "hypothesis.text", 'fuzzy_rate'])
for i in range(len(test_df)):
    
    df_2 = df_2.append({
                'reference.text': test_df["reference.text"],
                "hypothesis.text": test_df["hypothesis.text"],
                'fuzzy_rate': test_df.apply(get_ratio, axis=1),
             #   'confidence': confidence
            },ignore_index=True)

# %%
test_df.columns
# Out:
# Index(['identifier', 'speaker_id', 'file', 'corpus', 'configuration',
#        'machine', 'reference.text', 'hypothesis.text', 'scoring.wer',
#        'recomputed_wer', 'fuzzy_rate'],
#       dtype='object')

# %%
test_df_all = df[df['identifier'] == df['identifier']]

# %%
test_df_all["fuzzy_rate"]=test_df_all.apply(get_ratio, axis=1)

# %%
df_fuzzy = test_df_all.drop(['scoring.wer', 'recomputed_wer','identifier'],1)

# %%
df_fuzzy = df_fuzzy.drop(['speaker_id', 'file'],1)

# %%
df_fuzzy
# Out:
#                      corpus                                  configuration  \
# 1     switchboard_segmented                                 amazon__8000_8
# 2720  switchboard_segmented                                 amazon__8000_8
# 2721  switchboard_segmented                                 amazon__8000_8
# 2723  switchboard_segmented                                 amazon__8000_8
# 2727  switchboard_segmented                                 amazon__8000_8
# ...                     ...                                            ...
# 1325  switchboard_segmented  sphinx4__am_generic_ptm__lm_generic_p__8000_8
# 1344  switchboard_segmented  sphinx4__am_generic_ptm__lm_generic_p__8000_8
# 1348  switchboard_segmented  sphinx4__am_generic_ptm__lm_generic_p__8000_8
# 1303  switchboard_segmented  sphinx4__am_generic_ptm__lm_generic_p__8000_8
# 4016  switchboard_segmented  sphinx4__am_generic_ptm__lm_generic_p__8000_8
#
#       machine  \
# 1      amazon
# 2720   amazon
# 2721   amazon
# ...

# %%
aggr=df_fuzzy.groupby(["machine","corpus"]).agg(fuzzy_rate=("fuzzy_rate","mean")).reset_index().sort_values("fuzzy_rate")


aggr
# Out:
#     machine                 corpus  fuzzy_rate
# 66  sphinx4  switchboard_segmented   57.063348
# 60  sphinx4        ami_segmented_h   61.681453
# 64  sphinx4         rt_segmented_h   67.696237
# 63  sphinx4      librispeech_other   67.958175
# 40  mozilla        ami_segmented_h   71.245203
# ..      ...                    ...         ...
# 15   google                     st   97.536588
# 59       ms               voxforge   97.689391
# 25      ibm                     st   97.961538
# 5    amazon                     st   98.766304
# 55       ms                     st   99.153074
#
# [70 rows x 3 columns]

# %%
tokenized_sent
# Out:
# ['one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'uh',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'uh',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'a',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'a',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
# ...

# %%
len(word_embeddings)
# Out:
# 217

# %%
c2v_model = chars2vec.load_model('eng_50')


# Create word embeddings
word_embeddings = c2v_model.vectorize_words(tokenized_sent)
 
# Project embeddings on plane using the PCA
projection_2d = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)
 
# Draw words on plane
f = plt.figure(figsize=(20, 20))
 
for j in range(len(projection_2d)):
    plt.scatter(projection_2d[j, 0], projection_2d[j, 1],
                marker=('$' + tokenized_sent[j] + '$'),
                s=350 * len(tokenized_sent[j]), label=j,
                facecolors='green' if tokenized_sent[j]
                           in ref else 'black')

# %%
import chars2vec as c2v
import sklearn.decomposition
import matplotlib.pyplot as plt
import tensorflow as tf

""" Mute tensorflow warning """
tf.logging.set_verbosity(tf.logging.ERROR)

""" 2D Visualization script by using PCA on the vectorization of a list of words"""

c2v_model = chars2vec.load_model('eng_50')


word_embeddings = c2v_model.vectorize_words(tokenized_ref)

""" Optional print of euclidean distances between vectors """
def print_distance(words):
    import numpy as np

    print("\t", end = '')
    for word in words:
        print("%-10.6s" % word, end = '\t')
    print("")
    for i, vec1 in enumerate(word_embeddings):
        print(words[i], end = ' ')
        for vec2 in word_embeddings:
            print("%10.4f" % np.linalg.norm(vec1 - vec2), end = '\t')
        print("")

"""Embedding 2D projection with PCA"""
projection_2d = sklearn.decomposition.PCA(n_components=2).fit_transform(word_embeddings)

f = plt.figure(figsize=(8, 6))

for j in range(len(projection_2d)):
    plt.scatter(projection_2d[j, 0], projection_2d[j, 1],
                marker=('$' + tokenized_ref[j] + '$'),
                s=400 * len(tokenized_ref[j]), label=j,
                facecolors='red' if tokenized_ref[j]
                            in ref_all else 'black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-269-2c6ec3b0d6c4> in <module>
#      44                 s=400 * len(tokenized_ref[j]), label=j,
#      45                 facecolors='red' if tokenized_ref[j]
# ---> 46                             in ref_all else 'black')
#      47 plt.show()
#      48
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2840         vmin=None, vmax=None, alpha=None, linewidths=None, verts=None,
#    2841         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2842     __ret = gca().scatter(
#    2843         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2844         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# KeyboardInterrupt:

# %%
tokenized_sent
# Out:
# ['one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'uh',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'uh',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'a',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'a',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'i',
#  "'ve",
#  'heard',
#  'many',
#  'people',
#  'complain',
#  'about',
#  'the',
#  'school',
#  'systems',
#  'was',
#  'that',
# ...

# %%
#print_distance(projection_2d)

# %%
def find_knn(word, dictionnary, c2v_model, index, k = 80, filter = 1, distance = 1):
    ids, distances = index.knnQuery(c2v_model.vectorize([word]), k)
    if filter:
        knn = [dictionnary[i] for i in ids if levenshtein(word, dictionnary[i]) <= distance]
    else:
        knn = [dictionnary[i] for i in ids]
    if len(knn) == 0:
        knn = [dictionnary[i] for i in ids if levenshtein(word, dictionnary[i]) <= distance + 1]
    return knn

# %%
#find_knn("school",word_embeddings,c2v_model,5)

# %%
projection_2d

# %%
(tokenized_sent)

# %%
len(c2v_model.vectorize_words(words))
# Out:
# 16

# %%
projection = sklearn.decomposition.PCA(n_components=1).fit_transform(word_embeddings)

# %%
projection_2d
# Out:
# array([[-0.12526177, -0.64864993],
#        [-0.63993657, -0.9816613 ],
#        [-0.7119722 ,  0.2319031 ],
#        [ 0.3415184 ,  2.48213   ],
#        [-0.73717546,  0.91757494],
#        [-0.8734135 , -0.66021335],
#        [-0.6251857 , -0.685421  ],
#        [ 0.32867643, -0.17181301],
#        [-0.8295142 , -0.57128066],
#        [-0.14791928,  0.18905312],
#        [ 1.9456174 , -1.4613488 ],
#        [ 3.0520422 ,  0.5149292 ],
#        [-0.31774846,  0.01464987],
#        [-0.7119722 ,  0.2319035 ],
#        [ 1.161736  , -0.7878294 ],
#        [ 0.74098384,  1.3669217 ],
#        [-0.8909442 , -0.33586007],
#        [-0.7371777 ,  0.91757244],
#        [-0.12526195, -0.64864916],
#        [-0.6399302 , -0.9816625 ],
#        [-0.7119722 ,  0.23190351],
#        [ 0.34151736,  2.482131  ],
#        [-0.73717767,  0.91757244],
#        [-0.8734105 , -0.6602147 ],
#        [-0.6251856 , -0.6854208 ],
#        [ 0.32867515, -0.17181288],
#        [-0.8295146 , -0.57128054],
# ...

# %%
for j in range(len(projection_2d)):
    print(tokenized_sent[j],projection_2d[j,0],projection_2d[j,1])
# Out:
# one -0.12526177 -0.64864993
# of -0.63993657 -0.9816613
# the -0.7119722 0.2319031
# things 0.3415184 2.48213
# that -0.73717546 0.91757494
# i -0.8734135 -0.66021335
# 've -0.6251857 -0.685421
# heard 0.32867643 -0.17181301
# uh -0.8295142 -0.57128066
# many -0.14791928 0.18905312
# people 1.9456174 -1.4613488
# complain 3.0520422 0.5149292
# about -0.31774846 0.014649869
# the -0.7119722 0.2319035
# school 1.161736 -0.7878294
# systems 0.74098384 1.3669217
# was -0.8909442 -0.33586007
# that -0.7371777 0.91757244
# one -0.12526195 -0.64864916
# of -0.6399302 -0.9816625
# the -0.7119722 0.23190351
# things 0.34151736 2.482131
# that -0.73717767 0.91757244
# i -0.8734105 -0.6602147
# 've -0.6251856 -0.6854208
# heard 0.32867515 -0.17181288
# uh -0.8295146 -0.57128054
# many -0.14791906 0.18905301
# people 1.9456167 -1.4613484
# complain 3.0520432 0.51492923
# about -0.31774855 0.014650119
# the -0.7119723 0.23190351
# school 1.1617362 -0.7878294
# systems 0.7409839 1.3669217
# ...

# %%
for j in range(len(projection)):
    print(tokenized_sent[j],  projection_2d[j,0] )
