# %%
import pandas as pd
reviews = pd.read_csv("ign.csv")

# %%
reviews
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# 5               5         Good
# 6               6        Awful
# 7               7      Amazing
# 8               8        Awful
# 9               9         Good
# 10             10         Good
# 11             11         Good
# 12             12         Good
# 13             13      Amazing
# 14             14      Amazing
# 15             15         Okay
# 16             16         Okay
# 17             17        Great
# 18             18     Mediocre
# 19             19         Good
# 20             20         Good
# 21             21         Good
# 22             22         Good
# 23             23         Good
# 24             24      Amazing
# 25             25         Good
# 26             26      Amazing
# 27             27         Good
# 28             28        Great
# ...

# %%
revrev = reviews[(reviews['score_phrase']=='Amazing') | (reviews['score_phrase'] == 'Masterpiece')]
revrev
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7f0ff22111d8> in <module>
# ----> 1 revrev = reviews[(reviews['score_phrase']=='Amazing') | (reviews['score_phrase'] == 'Masterpiece')]
#       2 revrev
#
# NameError: name 'reviews' is not defined

# %%
p= revrev.groupby(['score_phrase','release_month'])['release_month'].count()

p
# Out:
# score_phrase  release_month
# Amazing       1                 87
#               2                136
#               3                168
#               4                104
#               5                 88
#               6                106
#               7                105
#               8                160
#               9                204
#               10               241
#               11               291
#               12               114
# Masterpiece   1                  6
#               2                  2
#               4                  5
#               5                  5
#               6                  8
#               7                  6
#               8                  3
#               9                  4
#               10                 7
#               11                 7
#               12                 2
# Name: release_month, dtype: int64

# %%
reviews['ten_perc'] = pd.qcut(reviews['score'],q=9)
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
reviews1 = reviews[['title','release_year','release_month', 'release_day','score']]
reviews1.sort_values(by=['release_year','release_month','release_day']).head()
# Out:
#                                                  title  release_year  \
# 516  The Walking Dead: The Game -- Episode 1: A New...          1970
# 515                                          Baku Baku          1996
# 488                                      Pilotwings 64          1996
# 514                                     Super Mario 64          1996
# 487                    Batman Forever: The Arcade Game          1996
#
#      release_month  release_day  score
# 516              1            1    8.5
# 515              6           18    7.0
# 488              9           25    8.2
# 514              9           25    9.8
# 487             11            2    5.0

# %%
reviews.shape
# Out:
# (18625, 11)

# %%
reviews2 = reviews[['title','release_year','score']]
reviews2
# Out:
#                                                    title  release_year  score
# 0                                LittleBigPlanet PS Vita          2012    9.0
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...          2012    9.0
# 2                                   Splice: Tree of Life          2012    8.5
# 3                                                 NHL 13          2012    8.5
# 4                                                 NHL 13          2012    8.5
# 5                              Total War Battles: Shogun          2012    7.0
# 6                                    Double Dragon: Neon          2012    3.0
# 7                                           Guild Wars 2          2012    9.0
# 8                                    Double Dragon: Neon          2012    3.0
# 9                              Total War Battles: Shogun          2012    7.0
# 10                               Tekken Tag Tournament 2          2012    7.5
# ...

# %%
rev= reviews2.groupby('release_year').mean()['score'].reset_index()
rev
# Out:
#     release_year     score
# 0           1970  8.500000
# 1           1996  6.161745
# 2           1997  6.566341
# 3           1998  6.930678
# 4           1999  6.983484
# 5           2000  6.693589
# 6           2001  7.120494
# 7           2002  6.978526
# 8           2003  7.198246
# 9           2004  7.170712
# 10          2005  7.222426
# 11          2006  6.732864
# 12          2007  6.632547
# 13          2008  6.448146
# 14          2009  6.840368
# 15          2010  6.932869
# 16          2011  7.050326
# 17          2012  7.418327
# 18          2013  7.460489
# 19          2014  7.467598
# 20          2015  7.659452
# 21          2016  7.573451

# %%
rev.hist(column='score')
rev.hist(column='release_year')
rev.plot.bar(x='release_year', y='score')
rev.plot(x='release_year', y='score')
rev.plot.scatter(x='release_year', y='score', s=50, c='red')

# %%
reviews3 = reviews[['title','platform','score']]

reviews3

reviews3.sort_values(by=['score']).tail()

platf= reviews3.groupby(['platform']).mean().reset_index()
platf2 = platf.sort_values(by=['score']).tail()

# %%
platf.plot(x='platform', y='score')

# %%
score1 = reviews1.groupby('release_month').mean()['score']


score1
# Out:
# release_month
# 1     6.694681
# 2     6.998116
# 3     7.023776
# 4     6.890744
# 5     6.860105
# 6     6.936413
# 7     6.854286
# 8     7.079895
# 9     7.237024
# 10    7.067143
# 11    6.943734
# 12    6.624850
# Name: score, dtype: float64

# %%
score2 = reviews[reviews['score']>8.9]
score3 = score2.groupby('release_month')['score'].count()
score3
# Out:
# release_month
# 1      93
# 2     138
# 3     168
# 4     109
# 5      93
# 6     114
# 7     111
# 8     163
# 9     208
# 10    248
# 11    298
# 12    116
# Name: score, dtype: int64

# %%
score4 = score2.groupby('release_month').mean()['score']
score4
# Out:
# release_month
# 1     9.201075
# 2     9.157246
# 3     9.171429
# 4     9.189908
# 5     9.255914
# 6     9.214035
# 7     9.154955
# 8     9.219632
# 9     9.185577
# 10    9.211694
# 11    9.238591
# 12    9.175862
# Name: score, dtype: float64

# %%
score3.plot.bar(x='release_month', y='score')
None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-348387c7f81b> in <module>
# ----> 1 reviews['ten_perc'] = pd.qcut(reviews[score],q=9)
#       2 reviews.head()
#
# NameError: name 'score' is not defined

# %%
reviews.corr()
# Out:
#                Unnamed: 0     score  release_year  release_month  release_day
# Unnamed: 0       1.000000  0.035579      0.893394      -0.096676     0.010068
# score            0.035579  1.000000      0.062716       0.007632     0.020079
# release_year     0.893394  0.062716      1.000000      -0.115515     0.016867
# release_month   -0.096676  0.007632     -0.115515       1.000000    -0.067964
# release_day      0.010068  0.020079      0.016867      -0.067964     1.000000

# %%
reviews.loc[9,:]
# Out:
# Unnamed: 0                                                9
# score_phrase                                           Good
# title                             Total War Battles: Shogun
# url               /games/total-war-battles-shogun/pc-142564
# platform                                                 PC
# score                                                     7
# genre                                              Strategy
# editors_choice                                            N
# release_year                                           2012
# release_month                                             9
# release_day                                              11
# Name: 9, dtype: object

# %%
reviews.iloc[5,:]
# Out:
# Unnamed: 0                                                 5
# score_phrase                                            Good
# title                              Total War Battles: Shogun
# url               /games/total-war-battles-shogun/mac-142565
# platform                                           Macintosh
# score                                                      7
# genre                                               Strategy
# editors_choice                                             N
# release_year                                            2012
# release_month                                              9
# release_day                                               11
# Name: 5, dtype: object

# %%
sales = pd.read_csv("vgsales.csv")
sales
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %%
sales1 = sales[['Name','Year','Publisher','Global_Sales']]
sales1
sales1
# Out:
#                                                     Name    Year  \
# 0                                             Wii Sports  2006.0
# 1                                      Super Mario Bros.  1985.0
# 2                                         Mario Kart Wii  2008.0
# 3                                      Wii Sports Resort  2009.0
# 4                               Pokemon Red/Pokemon Blue  1996.0
# 5                                                 Tetris  1989.0
# 6                                  New Super Mario Bros.  2006.0
# 7                                               Wii Play  2006.0
# 8                              New Super Mario Bros. Wii  2009.0
# 9                                              Duck Hunt  1984.0
# 10                                            Nintendogs  2005.0
# 11                                         Mario Kart DS  2005.0
# 12                           Pokemon Gold/Pokemon Silver  1999.0
# ...

# %%
sales2=sales[['Name','Platform','Year','Global_Sales']]

# %%
sales2.sort_values(by=['Global_Sales'],ascending=True).tail()
# Out:
#                        Name Platform    Year  Global_Sales
# 4  Pokemon Red/Pokemon Blue       GB  1996.0         31.37
# 3         Wii Sports Resort      Wii  2009.0         33.00
# 2            Mario Kart Wii      Wii  2008.0         35.82
# 1         Super Mario Bros.      NES  1985.0         40.24
# 0                Wii Sports      Wii  2006.0         82.74

# %%
sales2.groupby(['Year'])['Global_Sales'].count()
s=sales2.groupby('Year').max()['Global_Sales']
# Out:
# Year
# 1980.0     4.31
# 1981.0     4.50
# 1982.0     7.81
# 1983.0     3.20
# 1984.0    28.31
# 1985.0    40.24
# 1986.0     6.51
# 1987.0     4.38
# 1988.0    17.28
# 1989.0    30.26
# 1990.0    20.61
# 1991.0     4.61
# 1992.0    11.18
# 1993.0    10.55
# 1994.0     9.30
# 1995.0     5.15
# 1996.0    31.37
# 1997.0    10.95
# 1998.0    14.64
# 1999.0    23.10
# 2000.0     6.39
# 2001.0    14.98
# 2002.0    16.15
# 2003.0     7.20
# 2004.0    20.81
# 2005.0    24.76
# 2006.0    82.74
# 2007.0    22.72
# 2008.0    35.82
# 2009.0    33.00
# 2010.0    21.82
# 2011.0    14.76
# 2012.0    14.03
# 2013.0    21.40
# 2014.0    11.98
# 2015.0    14.24
# 2016.0     4.77
# 2017.0     0.03
# 2020.0     0.29
# Name: Global_Sales, dtype: float64

# %%
sales2[sales2['Global_Sales'] == sales2['Global_Sales'].max()]
# Out:
#          Name Platform    Year  Global_Sales
# 0  Wii Sports      Wii  2006.0         82.74

# %%
sales2.iloc[sales2['Global_Sales'].idxmax()]
# Out:
# Name            Wii Sports
# Platform               Wii
# Year                  2006
# Global_Sales         82.74
# Name: 0, dtype: object

# %%
len(sales2['Name'].unique())
# Out:
# 11493

# %%
sales2['Global_Sales'].max()
# Out:
# 82.74

# %%
sales2['Name'].value_counts()[0:5]
# Out:
# Need for Speed: Most Wanted    12
# LEGO Marvel Super Heroes        9
# Madden NFL 07                   9
# Ratatouille                     9
# FIFA 14                         9
# Name: Name, dtype: int64

# %%
sales.plot.scatter(x='Year',y='Global_Sales')

# %%
merged=pd.merge(reviews,sales,how='inner',left_on='title',right_on='Name')
merged.shape
# Out:
# (21182, 22)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(reviews1, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020F0EC3F400>,
# ...
#       dtype=object)
