# %%
import pandas as pd
import psycopg2
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://ds_student:chainreaction@167.172.176.235:5432/ds_program')

print('Database session created')
# Out:
# Database session created

# %% [raw]
# with engine.connect() as con:
#     rs = con.execute("""
# SET search_path = lahman2017;
# SELECT * FROM batting
#
#     """)
#
#     for row in rs:
#         print (row)

# %%
con = engine.connect()

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;

select namefirst, namelast, hr from batting
join master
on master.playerid = batting.playerid
where yearid = 2002 
order by hr desc
limit 1
    """, con)

df_sql
# Out:
#   namefirst   namelast  hr
# 0      Alex  Rodriguez  57

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;

select yearid,teamid,sum(salary) from salaries
where yearid=2002
group by yearid,teamid
order by sum desc
Limit 1
    """, con)

df_sql
# Out:
#    yearid teamid          sum
# 0    2002    NYA  125928583.0

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;
select avg(ab/hr) as abhr, yearid, batting.playerid, master.namelast from batting
join master
on master.playerid = batting.playerid
where yearid=2002 and hr > 0
group by yearid, batting.playerid, master.namelast
order by abhr asc
    """, con)
    

df_sql
# Out:
#       abhr  yearid   playerid    namelast
# 0      7.0    2002   diazju01        Diaz
# 1      8.0    2002  bondsba01       Bonds
# 2      9.0    2002   josefe01        Jose
# 3      9.0    2002  thomeji01       Thome
# 4     10.0    2002  rodrial01   Rodriguez
# 5     10.0    2002   rossda01        Ross
# 6     10.0    2002  delgawi01     Delgado
# 7     11.0    2002  greento02      Greene
# 8     11.0    2002   sosasa01        Sosa
# 9     12.0    2002  persoro01      Person
# 10    12.0    2002  palmera01    Palmeiro
# 11    12.0    2002  garcika01      Garcia
# 12    12.0    2002  larsobr01      Larson
# 13    13.0    2002  berkmla01     Berkman
# 14    13.0    2002  tankede01  Tankersley
# 15    13.0    2002  thamema01      Thames
# 16    13.0    2002  gilesbr02       Giles
# 17    13.0    2002  ramirma02     Ramirez
# 18    13.0    2002  giambja01      Giambi
# 19    13.0    2002  restomi01   Restovich
# 20    13.0    2002  sneades01       Snead
# ...

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;
select (h+bb+hbp)/(ab+bb+hbp+sf) as b, yearid, master.namelast from batting
join master
on master.playerid = batting.playerid
where yearid=2002 and hr > 0
order by b desc
    """, con)

df_sql
# Out:
#             b  yearid   namelast
# 0    0.581699    2002      Bonds
# 1    0.483333    2002    Kinkade
# 2    0.480519    2002    Loretta
# 3    0.450311    2002      Giles
# 4    0.449807    2002    Ramirez
# 5    0.448529    2002      Pratt
# 6    0.445351    2002      Thome
# 7    0.435414    2002     Giambi
# 8    0.435407    2002     Giambi
# 9    0.435045    2002      Jones
# 10   0.428786    2002     Helton
# 11   0.421338    2002     Walker
# 12   0.420139    2002    Edmonds
# 13   0.417489    2002   Guerrero
# 14   0.416514    2002    Sweeney
# 15   0.414878    2002   Williams
# 16   0.414365    2002      Floyd
# 17   0.413139    2002      Abreu
# 18   0.409091    2002   Phillips
# 19   0.406897    2002     Kearns
# 20   0.406051    2002    Delgado
# 21   0.405172    2002     Kielty
# 22   0.404624    2002    Berkman
# 23   0.404145    2002  Sheffield
# 24   0.402948    2002   Martinez
# 25   0.402695    2002     Olerud
# 26   0.400868    2002    Bagwell
# ...

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;

select yearid, sum(w), master.namelast, teamid from pitching
join master
on master.playerid = pitching.playerid
where yearid Between 2000 and 2010 and teamid = 'NYA'
group by yearid, master.namelast, teamid
order by sum(w) desc
    """, con)

df_sql
# Out:
#      yearid   sum    namelast teamid
# 0      2003  21.0    Pettitte    NYA
# 1      2010  21.0    Sabathia    NYA
# 2      2008  20.0     Mussina    NYA
# 3      2001  20.0     Clemens    NYA
# 4      2007  19.0        Wang    NYA
# 5      2009  19.0    Sabathia    NYA
# 6      2000  19.0    Pettitte    NYA
# 7      2002  19.0       Wells    NYA
# 8      2006  19.0        Wang    NYA
# 9      2002  18.0     Mussina    NYA
# 10     2010  18.0      Hughes    NYA
# 11     2001  17.0     Mussina    NYA
# 12     2006  17.0     Johnson    NYA
# 13     2003  17.0     Mussina    NYA
# 14     2003  17.0     Clemens    NYA
# 15     2005  17.0     Johnson    NYA
# 16     2001  15.0    Pettitte    NYA
# 17     2007  15.0    Pettitte    NYA
# 18     2003  15.0       Wells    NYA
# 19     2006  15.0     Mussina    NYA
# 20     2009  14.0    Pettitte    NYA
# 21     2008  14.0    Pettitte    NYA
# 22     2004  14.0     Vazquez    NYA
# 23     2004  14.0      Lieber    NYA
# ...

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;

select sum(w), master.namelast, teamid from pitching
join master
on master.playerid = pitching.playerid
where yearid Between 2000 and 2010 and teamid = 'NYA'
group by master.namelast, teamid
order by sum(w) desc
    """, con)

df_sql
# Out:
#        sum     namelast teamid
# 0    123.0      Mussina    NYA
# 1    122.0     Pettitte    NYA
# 2     69.0      Clemens    NYA
# 3     55.0         Wang    NYA
# 4     48.0       Rivera    NYA
# 5     40.0     Sabathia    NYA
# 6     34.0        Wells    NYA
# 7     34.0      Johnson    NYA
# 8     32.0    Hernandez    NYA
# 9     31.0       Hughes    NYA
# 10    24.0      Vazquez    NYA
# 11    23.0      Burnett    NYA
# 12    23.0      Mendoza    NYA
# 13    19.0      Stanton    NYA
# 14    18.0  Chamberlain    NYA
# 15    18.0       Wright    NYA
# 16    15.0    Contreras    NYA
# 17    14.0       Aceves    NYA
# 18    14.0        Brown    NYA
# 19    14.0       Gordon    NYA
# 20    14.0       Lieber    NYA
# 21    12.0       Bruney    NYA
# 22    12.0       Chacon    NYA
# 23    12.0       Weaver    NYA
# 24    11.0      Proctor    NYA
# 25    11.0      Sturtze    NYA
# 26    10.0        Small    NYA
# 27    10.0    Robertson    NYA
# 28     9.0       Nelson    NYA
# ...

# %%
df_sql = pd.read_sql_query("""
SET search_path = lahman2017;

select sum(bb), yearid, teamid from batting
join master
on master.playerid = batting.playerid
where yearid Between 2000 and 2010 and teamid = 'NYA'
group by yearid, teamid
order by yearid,sum(bb) desc
    """, con)

df_sql
# Out:
#       sum  yearid teamid
# 0   631.0    2000    NYA
# 1   519.0    2001    NYA
# 2   640.0    2002    NYA
# 3   684.0    2003    NYA
# 4   670.0    2004    NYA
# 5   637.0    2005    NYA
# 6   649.0    2006    NYA
# 7   637.0    2007    NYA
# 8   535.0    2008    NYA
# 9   663.0    2009    NYA
# 10  662.0    2010    NYA

# %%
 df_sql = pd.read_sql_query("""
SET search_path = lahman2017;

select teamid from pitching
join master
on master.playerid = pitching.playerid
where yearid Between 2000 and 2010 and teamid = 'NYA'
group by master.namelast, teamid
order by sum(w) desc
    """, con)

df_sql
